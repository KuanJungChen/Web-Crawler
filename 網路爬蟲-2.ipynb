# %%
from selenium import webdriver
driver = webdriver.Chrome()
driver.get('https://amis.afa.gov.tw/veg/VegProdDayTransInfo.aspx')#寫入網址

# %%
import pandas as pd
data = pd.read_html(driver.page_source)
#讀取頁面程式

# %%
data[8]
#在頁面表格8
# Out:
#               0            1      2     3     4          5          6  \
# 0            日期           產品     上價    中價    下價  平均價(元/公斤)  跟前一交易日比較%
# 1            小計           小計    NaN   NaN   NaN       16.2        NaN
# 2     109/03/01      FA1 黃秋葵   89.3  52.8  37.3       52.4       - 31
# 3     109/03/01   FB1 花椰菜 青梗   14.8  11.5   6.3       12.0        - 9
# 4     109/03/01    FC1 胡瓜 黑刺   32.4  22.5  14.6       22.9       - 10
# ...         ...          ...    ...   ...   ...        ...        ...
# 2159  109/03/15   SV2 蘆筍 綠蘆筍  100.6  75.6  57.1       77.9        - 6
# 2160  109/03/15   SV3 蘆筍 蘆筍花   99.3  80.4  71.0       84.4        - 1
# 2161  109/03/15    SV9 蘆筍 進口   95.7  88.6  71.7       87.2       - 23
# 2162  109/03/15     SW1 球莖甘藍    9.2   7.2   4.8        6.7       - 16
# 2163  109/03/15  SX1 芽菜類 綠豆芽   17.0  17.0  17.0       17.0          0
#
#             7          8
# 0     交易量(公斤)  跟前一交易日比較%
# 1     1978982        NaN
# 2          56       +143
# 3        6835        - 1
# 4         958       - 39
# ...       ...        ...
# 2159      471       + 33
# 2160       94        + 1
# 2161      256       +198
# 2162     3128       - 18
# 2163      180          0
#
# [2164 rows x 9 columns]

# %%
df = pd.DataFrame(price)
#原為list改為dataframe

# %%
df.to_excel("data1.xlsx", index=False)
#寫入excel
